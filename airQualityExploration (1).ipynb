# %% [markdown]
# Vito,Saverio. (2016). Air Quality. UCI Machine Learning Repository. https://doi.org/10.24432/C59K5F.

# %% [markdown]
# Trying to predict NOx concentration

# %%
from ucimlrepo import fetch_ucirepo 
import pandas as pd
# fetch dataset 
air_quality = fetch_ucirepo(id=360) 
# data (as pandas dataframes) 
x = air_quality.data.features 
# none
y = air_quality.data.targets 
  
# metadata 
print("metadata")
print(air_quality.metadata) 
  
# variable information 
print("variables")
print(air_quality.variables)
# Out:
# metadata
# ...

# %%
x["datetime"] = pd.to_datetime(x["Date"] + " " + x["Time"])

x = x.drop(columns=['Date', 'Time'])
x.where(x != -200, inplace=True)
x.dropna(inplace=True)
x.describe()
# Out:
#            CO(GT)  PT08.S1(CO)     NMHC(GT)    C6H6(GT)  PT08.S2(NMHC)  \
# count  827.000000   827.000000   827.000000  827.000000     827.000000
# mean     2.353567  1207.879081   231.025393   10.771100     966.116082
# min      0.300000   753.000000     7.000000    0.500000     448.000000
# 25%      1.300000  1017.000000    77.000000    4.800000     754.000000
# 50%      2.000000  1172.000000   157.000000    9.100000     944.000000
# 75%      3.100000  1380.000000   318.500000   14.800000    1142.500000
# max      8.100000  2040.000000  1189.000000   39.200000    1754.000000
# std      1.409496   241.816997   208.461912    7.418134     266.424557
#
#           NOx(GT)  PT08.S3(NOx)     NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  827.000000    827.000000  827.000000    827.000000   827.000000
# mean   143.501814    963.297461  100.259976   1600.620314  1045.812576
# min     12.000000    461.000000   19.000000    955.000000   263.000000
# ...

# %%
x.head(10)
# Out:
#     CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0      2.6       1360.0     150.0      11.9         1046.0    166.0
# 1      2.0       1292.0     112.0       9.4          955.0    103.0
# 2      2.2       1402.0      88.0       9.0          939.0    131.0
# 3      2.2       1376.0      80.0       9.2          948.0    172.0
# 4      1.6       1272.0      51.0       6.5          836.0    131.0
# 5      1.2       1197.0      38.0       4.7          750.0     89.0
# 6      1.2       1185.0      31.0       3.6          690.0     62.0
# 7      1.0       1136.0      31.0       3.3          672.0     62.0
# 8      0.9       1094.0      24.0       2.3          609.0     45.0
# 11     0.7       1066.0       8.0       1.1          512.0     16.0
#
#     PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  \
# 0         1056.0    113.0        1692.0       1268.0  13.6  48.9  0.7578
# ...

# %%
for c in x.columns:
    if (c != "datetime"):
        x.plot.scatter(x="datetime", y=c)

# %%
useful_features = []
for c in x.columns:
    if (c != "NOx(GT)" and c != "PT08.S3(NOx)" and c != "datetime" ):
        x.plot.scatter(x="NOx(GT)", y=c)
        correlation = x["NOx(GT)"].corr(x[c])
        print(correlation)
        # useful features at 10% significance
        if (abs(correlation) > 0.9) :
            useful_features.append(c)
# Out:
# 0.9513416643262227
# 0.922884580966318
# 0.8111819713709082
# 0.9273038172619257
# 0.9266333250032832
# 0.8574250058775139
# 0.9127236844919732
# 0.8933808293306169
# 0.2383948730750082
# -0.04197541215129795
# 0.2706792791439167
# -0.27801016480214064

# %%
useful_features
# Out:
# ['CO(GT)', 'PT08.S1(CO)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'PT08.S4(NO2)']
